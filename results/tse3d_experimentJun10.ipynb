# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np

# Use os.getcwd() to get the current working directory
main_directory = os.getcwd()
parent_directory = os.path.dirname(main_directory)
parent_directory = os.path.dirname(parent_directory)

# Define the subdirectories you want to add to sys.path
subdirs = ['MaSeq', 'marcos_client']

# Add the subdirectories to sys.path
for subdir in subdirs:
    full_path = os.path.join(parent_directory, subdir)
    sys.path.append(full_path)
#******************************************************************************
from seq.tse_3d_pseq import TSE3DPSEQ
seq = TSE3DPSEQ()
# Out:
# d:\app\Python\Python312\Lib\site-packages\cupy\_environment.py:217: UserWarning: CUDA path could not be detected. Set CUDA_PATH environment variable if CuPy fails to load.
#   warnings.warn(
# d:\app\Python\Python312\Lib\site-packages\sigpy\config.py:27: UserWarning: Importing cupy.cuda.cudnn failed. For more details, see the error stack below:
# DLL load failed while importing cudnn: 找不到指定的模块。
#   warnings.warn(

# %%
params = {
    'nScans': 1, 'larmorFreq': 10.33309, 'rfExFA': 90, 'rfReFA': 180, 'rfExTime': 400.0, 
    'rfExTime': 400.0, 'rfReTime': 800.0, 'repetitionTime': 1000.0, 'preExTime': 0.0,
    'inversionTime': 0.0, 'fov': [100.0, 100.0, 20.0], 'dfov': [0.0, 0.0, 0.0],
    'nPoints': [128, 128, 4], 'axesOrientation': [1, 2, 0], 'angle': 0.0,
    'rotationAxis': [0, 0, 1], 'bandwidth': 21.33333333333333, 'DephTime': 1.0,
    'riseTime': 0.10, 'shimming': [0.0015, 0.0020, 0.005], 'etl': 8,
    'echoSpacing': 20.0, 'dummyPulses': 0, 'sweepMode': 1
}
seq.mapVals.update(params)
seq.sequenceAtributes()
seq.sequenceRun(plotSeq=False, demo=False, standalone=True)
print(f'------------ max abs value: {np.abs(seq.mapVals['data_full']).max()}')
seq.sequenceAnalysis(mode='Standalone')
# Out:
# Max rd gradient amplitude: 5.0 mT/m
# Max ph gradient amplitude: 2.3 mT/m
# Max sl gradient amplitude: 0.4 mT/m
# Number of acquired slices: 2
# Creating batch_1.seq...
# read 6 definitions, 577 blocks, 4 shapes, 1 adc events, 2 rf events, 258 gradient shapes
# batch_1.seq ready!
# 1 batches created with 32768 read points. Sequence ready!
# Center frequecy set: 10.33309 MHz
# Scan 1, batch 1/1 running...
# Acquired points = 98304, Expected points = 98304
# Scan 1, batch 1/1 ready!
# ------------ max abs value: 5.172527869121884
# Moved: raw_data_20250610_000513 to experiments/acquisitions/2025.06.10
# [{'widget': 'image',
#   'data': array([[[18.8309727 , 28.90655431, 33.56456931, ..., 27.33691393,
#            29.17844637, 23.32896069],
#           [ 8.14328079, 33.75862968, 26.82609863, ..., 35.50544756,
#            12.56254842, 14.06759944],
#           [14.33221057, 16.45225734, 11.5684225 , ...,  3.87702237,
#            51.92732645, 18.84393428],
#           ...,
#           [ 5.26242766, 25.91279132, 25.97671167, ..., 19.50440572,
#            25.78789933, 17.43722721],
#           [31.78616424, 20.6523257 ,  3.00582959, ..., 45.47649308,
#            12.02606035,  7.88008198],
#           [11.95086613, 30.62227328, 16.29013128, ..., 13.79123249,
#            17.48450205, 10.82975143]],
#
#          [[23.25083881, 31.36960484, 28.37134475, ..., 38.53476421,
#            20.91927235,  9.43792198],
#           [ 5.34533809,  6.01103118, 24.55772401, ..., 20.33284763,
#             9.64259472,  8.56542525],
#           [47.27715395, 12.5159823 , 19.69570222, ..., 22.29656436,
#            16.38814928, 14.01459126],
#           ...,
#           [ 8.83435645, 19.09339291, 19.49584996, ...,  3.99617193,
#            14.1338645 , 15.60866766],
#           [10.91806344,  8.95384715, 26.96176737, ...,  2.0391156 ,
#            32.29911996, 16.90307465],
#           [14.01517183, 12.28275829, 31.24066781, ..., 14.6706319 ,
#            31.46520823, 11.49663517]]]),
#   'xLabel': 'X',
#   'yLabel': 'Y',
#   'title': 'Reconstructed image',
#   'row': 0,
#   'col': 0},
#  {'widget': 'image',
#   'data': array([[[1.00028675, 0.11918061, 0.67343887, ..., 0.73321246,
#            0.23709191, 0.79816828],
#           [0.41301279, 0.39551888, 0.62632022, ..., 0.93107751,
#            1.60110806, 0.38367126],
#           [0.50311272, 2.0597797 , 0.35640256, ..., 0.82459061,
#            0.43332767, 0.55825517],
#           ...,
#           [0.73371846, 0.31724768, 1.53689222, ..., 0.97354158,
#            0.42140235, 0.61915715],
#           [0.41103992, 1.15016782, 0.87197095, ..., 0.02745905,
#            0.3714392 , 0.7624945 ],
#           [0.55672649, 1.35475385, 0.79677784, ..., 1.45656766,
#            0.27883856, 0.56597805]],
#
#          [[1.1866278 , 0.06082507, 1.64870253, ..., 0.77134903,
#            0.65608646, 0.39426792],
#           [0.42001715, 1.11839924, 0.33084628, ..., 1.09647562,
#            0.55429742, 0.46887882],
#           [0.67243097, 1.19600843, 0.43320623, ..., 0.74813739,
#            0.47335908, 0.51901401],
#           ...,
#           [0.54271737, 0.56587422, 0.25975587, ..., 0.18049422,
#            0.9951548 , 0.7039573 ],
#           [1.07310232, 0.4049543 , 0.9525185 , ..., 0.7317219 ,
#            0.25602446, 0.76094383],
#           [1.14528362, 0.16499241, 0.29874076, ..., 0.7444708 ,
#            0.71048878, 0.54521259]]]),
#   'xLabel': 'kz',
#   'yLabel': 'ky',
#   'title': 'k-Space',
#   'row': 0,
#   'col': 1}]
